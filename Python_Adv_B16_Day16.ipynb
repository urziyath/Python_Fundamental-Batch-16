# %%
 print('Bismillah')
# Out:
# Bismillah

# %%
Continuation of Matplotlib:
#Getting started with datasets

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
sd = pd.read_csv('sample_data.csv')
                                          #2D
sd
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
#to know the type

type(sd)
# Out:
# pandas.core.frame.DataFrame

# %%
#to access particular col:
                                       #1D
sd.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sd.column_c)
# Out:
# pandas.core.series.Series

# %%
# To plot col a,colb and colc

# %%
plt.plot(sd.column_a,sd.column_b)
plt.plot(sd.column_a,sd.column_c)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Data Processing')
plt.legend(['a&b','a&c'])
plt.show()

# %%
#using countries.csv file

# %%
data = pd.read_csv('countries.csv')

data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
Req: Comparing the population of US and China

# %%
us = data[data.country == 'United States']

us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china = data[data.country == 'China']

china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year,us.population/10**6)
plt.plot(china.year,china.population/10**6)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Comparison Of Population')
plt.legend(['US','China'])
plt.show()

# %% [markdown]
# # Today's Assignment:
# Req : comparison of countries
#       10 countries ---> 5 graphs

# %%
1 : #comparison of India and China

# %%
ind = data[data.country == 'India']

ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
plt.plot(ind.year,ind.population/10**6)
plt.plot(china.year,china.population/10**6)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('India Vs China Population')
plt.legend(['India','China'])
plt.show()

# %%
2 : #comparison of Netherlands Vs Germany

# %%
nl = data[data.country == 'Netherlands']

nl
# Out:
#           country  year  population
# 1080  Netherlands  1952    10381988
# 1081  Netherlands  1957    11026383
# 1082  Netherlands  1962    11805689
# 1083  Netherlands  1967    12596822
# 1084  Netherlands  1972    13329874
# 1085  Netherlands  1977    13852989
# 1086  Netherlands  1982    14310401
# 1087  Netherlands  1987    14665278
# 1088  Netherlands  1992    15174244
# 1089  Netherlands  1997    15604464
# 1090  Netherlands  2002    16122830
# 1091  Netherlands  2007    16570613

# %%
ger = data[data.country == 'Germany']

ger
# Out:
#      country  year  population
# 564  Germany  1952    69145952
# 565  Germany  1957    71019069
# 566  Germany  1962    73739117
# 567  Germany  1967    76368453
# 568  Germany  1972    78717088
# 569  Germany  1977    78160773
# 570  Germany  1982    78335266
# 571  Germany  1987    77718298
# 572  Germany  1992    80597764
# 573  Germany  1997    82011073
# 574  Germany  2002    82350671
# 575  Germany  2007    82400996

# %%
plt.plot(nl.year,nl.population/10**6)
plt.plot(ger.year,ger.population/10**6)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Netherlands Vs Germany Population')
plt.legend(['Netherlands','Germany'])
plt.show()

# %%
3: #comparison of France and Croatia

# %%
croatia = data[data.country == 'Croatia']

croatia
# Out:
#      country  year  population
# 372  Croatia  1952     3882229
# 373  Croatia  1957     3991242
# 374  Croatia  1962     4076557
# 375  Croatia  1967     4174366
# 376  Croatia  1972     4225310
# 377  Croatia  1977     4318673
# 378  Croatia  1982     4413368
# 379  Croatia  1987     4484310
# 380  Croatia  1992     4494013
# 381  Croatia  1997     4444595
# 382  Croatia  2002     4481020
# 383  Croatia  2007     4493312

# %%
france = data[data.country == 'France']

france
# Out:
#     country  year  population
# 528  France  1952    42459667
# 529  France  1957    44310863
# 530  France  1962    47124000
# 531  France  1967    49569000
# 532  France  1972    51732000
# 533  France  1977    53165019
# 534  France  1982    54433565
# 535  France  1987    55630100
# 536  France  1992    57374179
# 537  France  1997    58623428
# 538  France  2002    59925035
# 539  France  2007    61083916

# %%
plt.plot(croatia.year,croatia.population/10**6)
plt.plot(france.year,france.population/10**6)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Croatia Vs France Population')
plt.legend(['Croatia','France'])
plt.show()

# %%
4: Comparison Of Pak vs Ban

# %%
pak = data[data.country == 'Pakistan']

pak
# Out:
#        country  year  population
# 1164  Pakistan  1952    41346560
# 1165  Pakistan  1957    46679944
# 1166  Pakistan  1962    53100671
# 1167  Pakistan  1967    60641899
# 1168  Pakistan  1972    69325921
# 1169  Pakistan  1977    78152686
# 1170  Pakistan  1982    91462088
# 1171  Pakistan  1987   105186881
# 1172  Pakistan  1992   120065004
# 1173  Pakistan  1997   135564834
# 1174  Pakistan  2002   153403524
# 1175  Pakistan  2007   169270617

# %%
ban = data[data.country == 'Bangladesh']

ban
# Out:
#         country  year  population
# 96   Bangladesh  1952    46886859
# 97   Bangladesh  1957    51365468
# 98   Bangladesh  1962    56839289
# 99   Bangladesh  1967    62821884
# 100  Bangladesh  1972    70759295
# 101  Bangladesh  1977    80428306
# 102  Bangladesh  1982    93074406
# 103  Bangladesh  1987   103764241
# 104  Bangladesh  1992   113704579
# 105  Bangladesh  1997   123315288
# 106  Bangladesh  2002   135656790
# 107  Bangladesh  2007   150448339

# %%
plt.plot(pak.year,pak.population/10**6)
plt.plot(ban.year,ban.population/10**6)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Pakistan Vs Bangladesh Population')
plt.legend(['Pakistan','Bangladesh'])
plt.show()

# %%
5: Comparison Of Syria and Saudi Arabia

# %%
syria = data[data.country == 'Syria']

syria
# Out:
#      country  year  population
# 1488   Syria  1952     3661549
# 1489   Syria  1957     4149908
# 1490   Syria  1962     4834621
# 1491   Syria  1967     5680812
# 1492   Syria  1972     6701172
# 1493   Syria  1977     7932503
# 1494   Syria  1982     9410494
# 1495   Syria  1987    11242847
# 1496   Syria  1992    13219062
# 1497   Syria  1997    15081016
# 1498   Syria  2002    17155814
# 1499   Syria  2007    19314747

# %%
sa = data[data.country == 'Saudi Arabia']

sa
# Out:
#            country  year  population
# 1308  Saudi Arabia  1952     4005677
# 1309  Saudi Arabia  1957     4419650
# 1310  Saudi Arabia  1962     4943029
# 1311  Saudi Arabia  1967     5618198
# 1312  Saudi Arabia  1972     6472756
# 1313  Saudi Arabia  1977     8128505
# 1314  Saudi Arabia  1982    11254672
# 1315  Saudi Arabia  1987    14619745
# 1316  Saudi Arabia  1992    16945857
# 1317  Saudi Arabia  1997    21229759
# 1318  Saudi Arabia  2002    24501530
# 1319  Saudi Arabia  2007    27601038

# %%
plt.plot(syria.year,syria.population/10**6)
plt.plot(sa.year,sa.population/10**6)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Syria Vs Saudi Arabia Population')
plt.legend(['Syria','Saudi Arabia'])
plt.show()

# %%
print('The End')
# Out:
# The End
